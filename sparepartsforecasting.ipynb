# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# Out:
# C:\Users\JESAL\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\JESAL\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\JESAL\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\JESAL\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# ...

# %%
service_data=pd.read_excel('service-data.xlsx')
service_data.head()
# Out:
#   Invoice Date Job Card Date Business Partner Name Vehicle No.  \
# 0   2017-05-30    2017-05-30        shivXXXXXXXXXX  KA03MFXXXX
# 1   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 2   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 3   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 4   2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
#
#               Vehicle Model  Current KM Reading INVOICE LINE TEXT
# 0  BAJAJ AVENGER STREET 220             50000.0        ENGINE OIL
# 1       BAJAJ PULSAR NS 200               758.0        ENGINE OIL
# 2       BAJAJ PULSAR NS 200               758.0            POLISH
# 3       BAJAJ PULSAR NS 200               758.0       CONSUMABLES
# 4       BAJAJ PULSAR NS 200               758.0       COOLANT OIL

# %%
service_data.shape
# Out:
# (28484, 7)

# %%
service_data.describe()
# Out:
#        Current KM Reading
# count        28482.000000
# mean         19348.003827
# std          25246.722306
# min              0.000000
# 25%           3988.000000
# 50%          12420.500000
# 75%          27905.000000
# max         610112.000000

# %%
service_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28484 entries, 0 to 28483
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Invoice Date           28482 non-null  datetime64[ns]
#  1   Job Card Date          28482 non-null  datetime64[ns]
#  2   Business Partner Name  28484 non-null  object
#  3   Vehicle No.            28484 non-null  object
#  4   Vehicle Model          28482 non-null  object
#  5   Current KM Reading     28482 non-null  float64
#  6   INVOICE LINE TEXT      28449 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 1.5+ MB

# %%
service_data
# Out:
#       Invoice Date Job Card Date Business Partner Name Vehicle No.  \
# 0       2017-05-30    2017-05-30        shivXXXXXXXXXX  KA03MFXXXX
# 1       2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 2       2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 3       2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# 4       2017-06-02    2017-05-31        KIRAXXXXXXXXXX  KA53ESXXXX
# ...            ...           ...                   ...         ...
# 28479   2019-01-06    2019-01-06        pravXXXXXXXXXX  KA53EVXXXX
# 28480   2019-01-06    2019-01-06        pravXXXXXXXXXX  KA53EVXXXX
# 28481   2019-01-06    2019-01-06        pravXXXXXXXXXX  KA53EVXXXX
# 28482          NaT           NaT            XXXXXXXXXX        XXXX
# 28483          NaT           NaT            XXXXXXXXXX        XXXX
#
#                   Vehicle Model  Current KM Reading   INVOICE LINE TEXT
# 0      BAJAJ AVENGER STREET 220             50000.0          ENGINE OIL
# ...

# %%
service_data.isnull().sum()
# Out:
# Invoice Date              2
# Job Card Date             2
# Business Partner Name     0
# Vehicle No.               0
# Vehicle Model             2
# Current KM Reading        2
# INVOICE LINE TEXT        35
# dtype: int64

# %%
service_data.drop(service_data.tail(2).index,inplace=True)

# %%
service_data.isnull().sum()
# Out:
# Invoice Date              0
# Job Card Date             0
# Business Partner Name     0
# Vehicle No.               0
# Vehicle Model             0
# Current KM Reading        0
# INVOICE LINE TEXT        34
# dtype: int64

# %%
from collections import Counter

# %%
Counter(service_data['INVOICE LINE TEXT'])
# Out:
# Counter({'ENGINE OIL': 3802,
#          'POLISH': 1245,
#          'CONSUMABLES': 1595,
#          'COOLANT OIL': 70,
#          'CHAIN LUBRICATION': 3441,
#          '4 WAY SWITCH': 2,
#          '3M OIL': 1628,
#          'GENERAL SERVICE': 2142,
#          'OIL FILTER': 821,
#          'INDICATOR': 110,
#          'HEAD REST': 56,
#          'VALVE GUIDE': 63,
#          'TIMMING CHAIN': 78,
#          'FOOT REST': 99,
#          'LOW BEAM BULB': 12,
#          'VALVE GRAINDING': 63,
#          'DISC PAD': 575,
#          'LOADING GEAR': 53,
#          'PACKING KIT': 56,
#          'TIMMING CHAIN PAD': 73,
#          'TENSIONER': 79,
#          'CLUTCH BELL REST': 21,
#          'CLUTCH ASSEMBLY': 212,
#          'VALVE KIT': 66,
#          'SPARK PLUG': 421,
#          'ONE WAY CLUTCH': 5,
#          'BORE KIT': 53,
#          'AIR FILTER': 1715,
#          'HEAD RUBBER': 18,
#          'CLUTCH CABLE': 263,
#          'CRANK SHAFT': 50,
#          'BRAKE ADJUSTMENT': 7,
# ...
